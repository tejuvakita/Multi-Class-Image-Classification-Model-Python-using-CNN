# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import os
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
# load the model
model = tf.keras.models.load_model("model.h5")
model_negative = tf.keras.models.load_model("model_negative.h5")

# %%
def predictImage(filename):
    img1 = image.load_img(filename,target_size=(224,224))
    
    plt.imshow(img1)
 
    Y = image.img_to_array(img1)
    
    X = np.expand_dims(Y,axis=0)
    print(X.shape)
    val = np.argmax(model.predict(X))
    print(val)
    if val == 0:
        
        plt.xlabel("driving license",fontsize=30)
        
    
    elif val == 1:
        
        plt.xlabel("social security",fontsize=30)

# %%
predictImage("./Testing Data/Others/101.jpg")
# Out:
# (1, 224, 224, 3)
# 0

# %%
def predictImage(filename):
    img1 = image.load_img(filename,target_size=(224,224))
    
    plt.imshow(img1)
 
    Y = image.img_to_array(img1)
    
    X = np.expand_dims(Y,axis=0)
    print(X.shape)
    val = np.argmax(model_negative.predict(X))
    print(val)
    if val == 0:
        
        plt.xlabel("driving license",fontsize=30)
        
    
    elif val == 1:
        
        plt.xlabel("social security",fontsize=30)
    elif val == 2:
        
        plt.xlabel("Others",fontsize=30)

# %%
predictImage("./Testing Data/Others/101.jpg")
# Out:
# (1, 224, 224, 3)
# 2
